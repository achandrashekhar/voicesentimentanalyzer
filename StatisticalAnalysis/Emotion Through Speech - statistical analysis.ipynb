# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
participant1_userresults = [1,6,1,10,5,9,14,1,1,2,1,3]
participant1_appresults = [1,2,1,2,5,3,8,1,1,2,1,1]

scipy.stats.chisquare(participant1_userresults, participant1_appresults)
# Out:
# Power_divergenceResult(statistic=60.5, pvalue=7.4858955271518427e-09)

# %%
participant2_userresults = [1,1,1,7,5,7,6,1,1,1,1,1]
participant2_appresults = [1,1,1,2,2,5,2,2,1,2,4,1]

scipy.stats.chisquare(participant2_userresults, participant2_appresults)
# Out:
# Power_divergenceResult(statistic=29.050000000000001, pvalue=0.0022297601869339803)

# %%
participant3_userresults = [1,2,1,2,5,2,2,1,1,3,1,2]
participant3_appresults = [1,2,1,2,5,3,7,2,3,3,1,1]

scipy.stats.chisquare(participant3_appresults, participant3_userresults)
# Out:
# Power_divergenceResult(statistic=18.5, pvalue=0.070680692649714383)

# %%
participant4_userresults = [1,1,1,10,7,4,10,1,4,1,1,6]
participant4_appresults = [1,1,1,3,5,8,7,1,3,2,1,3]

scipy.stats.chisquare(participant4_userresults, participant4_appresults)
# Out:
# Power_divergenceResult(statistic=24.25238095238095, pvalue=0.011710139125172039)

# %%
participant5_userresults = [1,1,1,5,5,3,2,1,1,1,1,1]
participant5_appresults = [1,3,1,2,5,3,2,1,1,2,1,2]

scipy.stats.chisquare(participant5_appresults, participant5_userresults)
# Out:
# Power_divergenceResult(statistic=7.7999999999999998, pvalue=0.73109966091107581)

# %%
combinedparticipant_true = [1,6,1,10,5,9,14,1,1,2,1,3,1,1,1,7,5,7,6,1,1,1,1,1,1,2,1,2,5,2,2,1,1,3,1,2,1,1,1,10,7,4,10,1,4,1,1,6,1,1,1,5,5,3,2,1,1,1,1,1]
combinedparticipant_pred = [1,2,1,2,5,3,8,1,1,2,1,1,1,1,1,2,2,5,2,2,1,2,4,1,1,2,1,2,5,3,7,2,3,3,1,1,1,1,1,3,5,8,7,1,3,2,1,3,1,3,1,2,5,3,2,1,1,2,1,2]

scipy.stats.chisquare(combinedparticipant_true, combinedparticipant_pred)
# Out:
# Power_divergenceResult(statistic=127.37380952380953, pvalue=6.1904674638949061e-07)

# %%
scipy.stats.wilcoxon(combinedparticipant_true, combinedparticipant_pred)
# Out:
# WilcoxonResult(statistic=120.5, pvalue=0.058914410136232845)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
user1_true = ["joy","sadness","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","anger"]
user1_pred = ["joy","sadness","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","joy"]

cm1 = confusion_matrix(user1_true,user1_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cm1, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
user2_true = ["joy","joy","joy","sadness","fear","anger","sadness","joy","joy","joy","joy","joy"]
user2_pred = ["joy","joy","joy","sadness","sadness","fear","sadness","sadness","joy","sadness","disgust","joy"]

cm2 = confusion_matrix(user2_true,user2_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cm2, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
user3_true = ["joy","sadness","joy","sadness","fear","sadness","sadness","joy","joy","anger","joy","sadness"]
user3_pred = ["joy","sadness","joy","sadness","fear","anger","sadness","sadness","anger","anger","joy","joy"]

cm3 = confusion_matrix(user3_true,user3_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cm3, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
user4_true = ["joy","joy","joy","anger","fear","disgust","sadness","joy","disgust","joy","joy","fear"]
user4_pred = ["joy","joy","joy","anger","fear","disgust","sadness","joy","anger","sadness","joy","anger"]

cm4 = confusion_matrix(user4_true,user4_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cm4, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
user5_true = ["joy","joy","joy","fear","fear","anger","sadness","joy","joy","joy","joy","sadness"]
user5_pred = ["joy","anger","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","sadness"]

cm5 = confusion_matrix(user5_true,user5_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cm5, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
combinedusers_true =["joy","sadness","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","anger","joy","joy","joy","sadness","fear","anger","sadness","joy","joy","joy","joy","joy","joy","sadness","joy","sadness","fear","sadness","sadness","joy","joy","anger","joy","sadness","joy","joy","joy","anger","fear","disgust","sadness","joy","disgust","joy","joy","fear","joy","joy","joy","fear","fear","anger","sadness","joy","joy","joy","joy","sadness"]
combinedusers_pred = ["joy","sadness","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","joy","joy","joy","joy","sadness","sadness","fear","sadness","sadness","joy","sadness","disgust","joy","joy","sadness","joy","sadness","fear","anger","sadness","sadness","anger","anger","joy","joy","joy","joy","joy","anger","fear","disgust","sadness","joy","anger","sadness","joy","anger","joy","anger","joy","sadness","fear","anger","sadness","joy","joy","sadness","joy","sadness"]

# %%
cmcomb = confusion_matrix(combinedusers_true,combinedusers_pred,labels=["joy","sadness","anger","disgust","fear"])

# %%
ax= plt.subplot()
sns.heatmap(cmcomb, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(["joy","sadness","anger","disgust","fear"])
ax.yaxis.set_ticklabels(["fear","disgust","anger","sadness","joy"])
plt.show()

# %%
accuracy_score(combinedusers_true,combinedusers_pred)
# Out:
# 0.73333333333333328
